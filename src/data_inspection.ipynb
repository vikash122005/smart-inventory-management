# %%
import pandas as pd

# %%
###Reading the csv file
bad_products = pd.read_csv("C:/Users/admin/OneDrive/Desktop/smart-inventory/data/raw/Sample bad/Products.csv")

# %%
bad_products.columns
# Out:
# Index(['product_id ', 'product_name ', 'product_category ', 'unit_price ',
#        'reorder_level ', 'lead_time_days '],
#       dtype='object')

# %%
###Cleaning rows with end white space
bad_products.columns = bad_products.columns.str.strip()

# %%
bad_products.columns
# Out:
# Index(['product_id', 'product_name', 'product_category', 'unit_price',
#        'reorder_level', 'lead_time_days'],
#       dtype='object')

# %%
###checking duplicates
bad_products[bad_products['product_id'].duplicated(keep = False)]
# Out:
#    product_id   product_name product_category  unit_price  reorder_level  \
# 4         NaN    Sugar 500gm          Grocery       -36.0           45.0
# 8        P009   3Broom stick        Household       850.0           10.0
# 9         NaN  Snickers 50gm           Snacks       -45.0           50.0
# 10       P009   3Broom stick        Household       850.0           10.0
# 11       P009   3Broom stick        Household       850.0           10.0
# 12        NaN            NaN              NaN         NaN            NaN
#
#     lead_time_days
# 4              2.0
# 8              0.0
# 9              2.0
# 10             0.0
# 11             0.0
# 12             NaN

# %%
###Missing product ID's
bad_products[bad_products['product_id'].isnull()]
# Out:
#    product_id   product_name product_category  unit_price  reorder_level  \
# 4         NaN    Sugar 500gm          Grocery       -36.0           45.0
# 9         NaN  Snickers 50gm           Snacks       -45.0           50.0
# 12        NaN            NaN              NaN         NaN            NaN
#
#     lead_time_days
# 4              2.0
# 9              2.0
# 12             NaN

# %%
###Null values in Products name
bad_products[bad_products['product_name'].isnull()]
# Out:
#    product_id product_name product_category  unit_price  reorder_level  \
# 12        NaN          NaN              NaN         NaN            NaN
#
#     lead_time_days
# 12             NaN

# %%
###To check if all rows are NULL
bad_products.isnull().all(axis = 1).sum()
# Out:
# np.int64(1)

# %%
###to drop a Row with all null values in a table
bad_products = bad_products.dropna(how="all")

# %%
###To check if all rows are NULL
bad_products.isnull().all(axis = 1).sum()
# Out:
# np.int64(0)

# %%
###checking duplicates
bad_products[bad_products['product_id'].duplicated(keep = False)]
# Out:
#    product_id   product_name product_category  unit_price  reorder_level  \
# 4         NaN    Sugar 500gm          Grocery       -36.0           45.0
# 8        P009   3Broom stick        Household       850.0           10.0
# 9         NaN  Snickers 50gm           Snacks       -45.0           50.0
# 10       P009   3Broom stick        Household       850.0           10.0
# 11       P009   3Broom stick        Household       850.0           10.0
#
#     lead_time_days
# 4              2.0
# 8              0.0
# 9              2.0
# 10             0.0
# 11             0.0

# %%
###check for exact duplicates
bad_products[bad_products['product_id']=="P009"].duplicated()
# Out:
# 8     False
# 10     True
# 11     True
# dtype: bool

# %%
###Drop duplicates
bad_products = bad_products.drop_duplicates()

# %%
###checking duplicates
bad_products[bad_products['product_id'].duplicated(keep = False)]
# Out:
#   product_id   product_name product_category  unit_price  reorder_level  \
# 4        NaN    Sugar 500gm          Grocery       -36.0           45.0
# 9        NaN  Snickers 50gm           Snacks       -45.0           50.0
#
#    lead_time_days
# 4             2.0
# 9             2.0

# %%
###check for exact duplicates
bad_products[bad_products['product_id']=="P009"].duplicated()
# Out:
# 8    False
# dtype: bool

# %%
bad_products.isnull().sum()
# Out:
# product_id          2
# product_name        0
# product_category    0
# unit_price          0
# reorder_level       0
# lead_time_days      0
# dtype: int64

# %%
bad_products[bad_products["product_id"] == "P009"]
# Out:
#   product_id  product_name product_category  unit_price  reorder_level  \
# 8       P009  3Broom stick        Household       850.0           10.0
#
#    lead_time_days
# 8             0.0

# %%
bad_products[bad_products["product_id"] == "P009"].duplicated()
# Out:
# 8    False
# dtype: bool

# %%
bad_products
# Out:
#    product_id       product_name product_category  unit_price  reorder_level  \
# 0        P001          USB cable      Electronics       666.0           30.0
# 1        P002         Headphones      Electronics       932.0           25.0
# 2        P003              Mouse      Electronics         0.0           20.0
# 3        P004          Rice 10Kg          Grocery       579.0           28.0
# 4         NaN        Sugar 500gm          Grocery       -36.0           45.0
# 5        P006  Wheat flour 500gm          Grocery        38.0           40.0
# 6        P007       Bucket combo        Household       486.0           20.0
# 7        P008       Home Cleaner        Household       520.0           15.0
# 8        P009       3Broom stick        Household       850.0           10.0
# 9         NaN      Snickers 50gm           Snacks       -45.0           50.0
# 13       P013  Wheat flour 500gm          Grocery        38.0           40.0
#
#     lead_time_days
# 0              4.0
# ...

# %%
bad_products[bad_products["unit_price"] < 0]
# Out:
#   product_id   product_name product_category  unit_price  reorder_level  \
# 4        NaN    Sugar 500gm          Grocery       -36.0           45.0
# 9        NaN  Snickers 50gm           Snacks       -45.0           50.0
#
#    lead_time_days
# 4             2.0
# 9             2.0

# %%
###separate invalid record
invalid_record = bad_products[bad_products["unit_price"] < 0]

# %%
invalid_record
# Out:
#   product_id   product_name product_category  unit_price  reorder_level  \
# 4        NaN    Sugar 500gm          Grocery       -36.0           45.0
# 9        NaN  Snickers 50gm           Snacks       -45.0           50.0
#
#    lead_time_days
# 4             2.0
# 9             2.0

# %%
bad_products[bad_products["product_id"].isnull()][["product_id","product_name","unit_price"]]
# Out:
#   product_id   product_name  unit_price
# 4        NaN    Sugar 500gm       -36.0
# 9        NaN  Snickers 50gm       -45.0

# %%
bad_products.isnull().sum()
# Out:
# product_id          2
# product_name        0
# product_category    0
# unit_price          0
# reorder_level       0
# lead_time_days      0
# dtype: int64

# %%
bad_products[bad_products["reorder_level"] < 0]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, product_category, unit_price, reorder_level, lead_time_days]
# Index: []

# %%
bad_products[bad_products["lead_time_days"] < 0]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, product_category, unit_price, reorder_level, lead_time_days]
# Index: []

# %%
bad_products.dtypes
# Out:
# product_id           object
# product_name         object
# product_category     object
# unit_price          float64
# reorder_level       float64
# lead_time_days      float64
# dtype: object

# %%
###Reading the csv file
bad_sales = pd.read_csv("C:/Users/admin/OneDrive/Desktop/smart-inventory/data/raw/Sample bad/Sales.csv")

# %%
bad_sales.head()
# Out:
#   sale_id  product_id            sale_date   quantity_sold
# 0     S001        P005  2026-09-05 17:32:15               1
# 1     S002        P005  2026-09-05 17:40:09               2
# 2     S003        P003  2026-09-05 17:53:48               1
# 3     S004        P004  2026-09-05 18:12:06               1
# 4     S005        P001  2026-09-05 18:40:03               1

# %%
bad_sales.columns
# Out:
# Index(['sale_id ', 'product_id ', 'sale_date ', 'quantity_sold '], dtype='object')

# %%
bad_sales.columns = bad_sales.columns.str.strip()

# %%
bad_sales.columns
# Out:
# Index(['sale_id', 'product_id', 'sale_date', 'quantity_sold'], dtype='object')

# %%
bad_sales.isnull().sum()
# Out:
# sale_id          0
# product_id       0
# sale_date        0
# quantity_sold    0
# dtype: int64

# %%
bad_sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
bad_sales["sale_id"].isnull().sum()
# Out:
# np.int64(0)

# %%
bad_sales["sale_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
bad_sales[~bad_sales["product_id"].isin(bad_products["product_id"])]
# Out:
#    sale_id product_id            sale_date  quantity_sold
# 0     S001       P005  2026-09-05 17:32:15              1
# 1     S002       P005  2026-09-05 17:40:09              2
# 17    S018       P010  2026-09-07 22:40:09              4
# 22    S023       P010  2026-09-08 23:51:01              2
# 24    S025       P010  2026-09-09 10:53:48              3
# 27    S028       P005  2026-09-09 11:48:27              2

# %%
bad_products[bad_products["product_id"].isin(["P005","P010"])]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, product_category, unit_price, reorder_level, lead_time_days]
# Index: []

# %%
invalid_sales = bad_sales[~bad_sales["product_id"].isin(bad_products["product_id"])]

# %%
invalid_sales
# Out:
#    sale_id product_id            sale_date  quantity_sold
# 0     S001       P005  2026-09-05 17:32:15              1
# 1     S002       P005  2026-09-05 17:40:09              2
# 17    S018       P010  2026-09-07 22:40:09              4
# 22    S023       P010  2026-09-08 23:51:01              2
# 24    S025       P010  2026-09-09 10:53:48              3
# 27    S028       P005  2026-09-09 11:48:27              2

# %%
bad_sales["sale_date"] = pd.to_datetime(bad_sales["sale_date"],errors="coerce")

# %%
invalid_sale_dates = bad_sales[bad_sales["sale_date"].isnull()]

# %%
invalid_sale_dates
# Out:
# Empty DataFrame
# Columns: [sale_id, product_id, sale_date, quantity_sold]
# Index: []

# %%
bad_sales[bad_sales["quantity_sold"] <= 0]
# Out:
# Empty DataFrame
# Columns: [sale_id, product_id, sale_date, quantity_sold]
# Index: []

# %%
bad_inventorys = pd.read_csv("C:/Users/admin/OneDrive/Desktop/smart-inventory/data/raw/Sample bad/Inventory.csv")

# %%
bad_inventorys.head()
# Out:
#   product_id   current_stock
# 0        P001              12
# 1        P002              15
# 2        P003              10
# 3        P004              17
# 4        P005               4

# %%
bad_inventorys.columns
# Out:
# Index(['product_id ', 'current_stock '], dtype='object')

# %%
bad_inventorys.columns = bad_inventorys.columns.str.strip()

# %%
bad_inventorys.columns
# Out:
# Index(['product_id', 'current_stock'], dtype='object')

# %%
bad_inventorys.isnull().sum()
# Out:
# product_id       0
# current_stock    0
# dtype: int64

# %%
bad_inventorys.duplicated().sum()
# Out:
# np.int64(0)

# %%
bad_inventorys["product_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
bad_inventorys[~bad_inventorys["product_id"].isin(bad_products["product_id"])]
# Out:
#   product_id  current_stock
# 4       P005              4
# 9       P010              1

# %%
invalid_inventory = bad_inventorys[~bad_inventorys["product_id"].isin(bad_products["product_id"])]

# %%
invalid_inventory
# Out:
#   product_id  current_stock
# 4       P005              4
# 9       P010              1

# %%
bad_inventorys[bad_inventorys["current_stock"]<0 ]
# Out:
# Empty DataFrame
# Columns: [product_id, current_stock]
# Index: []

# %%
invalid_products = bad_products[
    bad_products["product_id"].isna() |
    (bad_products["unit_price"] < 0)
]

# %%
clean_products = bad_products.drop(invalid_products.index)

# %%
invalid_products
# Out:
#   product_id   product_name product_category  unit_price  reorder_level  \
# 4        NaN    Sugar 500gm          Grocery       -36.0           45.0
# 9        NaN  Snickers 50gm           Snacks       -45.0           50.0
#
#    lead_time_days
# 4             2.0
# 9             2.0

# %%
clean_products
# Out:
#    product_id       product_name product_category  unit_price  reorder_level  \
# 0        P001          USB cable      Electronics       666.0           30.0
# 1        P002         Headphones      Electronics       932.0           25.0
# 2        P003              Mouse      Electronics         0.0           20.0
# 3        P004          Rice 10Kg          Grocery       579.0           28.0
# 5        P006  Wheat flour 500gm          Grocery        38.0           40.0
# 6        P007       Bucket combo        Household       486.0           20.0
# 7        P008       Home Cleaner        Household       520.0           15.0
# 8        P009       3Broom stick        Household       850.0           10.0
# 13       P013  Wheat flour 500gm          Grocery        38.0           40.0
#
#     lead_time_days
# 0              4.0
# 1              6.0
# 2              7.0
# 3              3.0
# 5              2.0
# 6              4.0
# 7              3.0
# 8              0.0
# ...

# %%
clean_sales = bad_sales.drop(invalid_sales.index)

# %%
clean_inventory = bad_inventorys.drop(invalid_inventory.index)

# %%
clean_inventory
# Out:
#   product_id  current_stock
# 0       P001             12
# 1       P002             15
# 2       P003             10
# 3       P004             17
# 5       P006              2
# 6       P007              6
# 7       P008              9
# 8       P009             10

# %%
clean_sales[~clean_sales["product_id"].isin(clean_products["product_id"])]
# Out:
# Empty DataFrame
# Columns: [sale_id, product_id, sale_date, quantity_sold]
# Index: []

# %%
clean_inventory[~clean_inventory["product_id"].isin(clean_products["product_id"])]
# Out:
# Empty DataFrame
# Columns: [product_id, current_stock]
# Index: []

# %%
clean_products[~clean_products["product_id"].isin(clean_inventory["product_id"])]
# Out:
#    product_id       product_name product_category  unit_price  reorder_level  \
# 13       P013  Wheat flour 500gm          Grocery        38.0           40.0
#
#     lead_time_days
# 13             2.0

# %%
clean_products["product_id"].isnull().sum()
# Out:
# np.int64(0)

# %%
clean_products[clean_products["product_id"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, product_category, unit_price, reorder_level, lead_time_days]
# Index: []

# %%
clean_products[clean_products["lead_time_days"]<0]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, product_category, unit_price, reorder_level, lead_time_days]
# Index: []

# %%
clean_sales[clean_sales["sale_id"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [sale_id, product_id, sale_date, quantity_sold]
# Index: []

# %%
clean_sales[clean_sales["sale_id"].isnull()]
# Out:
# Empty DataFrame
# Columns: [sale_id, product_id, sale_date, quantity_sold]
# Index: []

# %%
clean_sales[clean_sales["quantity_sold"]<= 0]
# Out:
# Empty DataFrame
# Columns: [sale_id, product_id, sale_date, quantity_sold]
# Index: []

# %%
clean_inventory[clean_inventory["current_stock"]<=0]
# Out:
# Empty DataFrame
# Columns: [product_id, current_stock]
# Index: []

# %%
clean_products.dtypes
# Out:
# product_id           object
# product_name         object
# product_category     object
# unit_price          float64
# reorder_level       float64
# lead_time_days      float64
# dtype: object

# %%
clean_sales.dtypes
# Out:
# sale_id                  object
# product_id               object
# sale_date        datetime64[ns]
# quantity_sold             int64
# dtype: object

# %%
clean_inventory.dtypes
# Out:
# product_id       object
# current_stock     int64
# dtype: object

# %%
clean_products["reorder_level"] = clean_products["reorder_level"].astype(int)

# %%
clean_products["lead_time_days"] = clean_products["lead_time_days"].astype(int)

# %%
clean_products.dtypes
# Out:
# product_id           object
# product_name         object
# product_category     object
# unit_price          float64
# reorder_level         int64
# lead_time_days        int64
# dtype: object

# %%
clean_products.to_csv("C:/Users/admin/OneDrive/Desktop/smart-inventory/data/processed/products_clean.csv",index = False)

# %%
clean_sales.to_csv("C:/Users/admin/OneDrive/Desktop/smart-inventory/data/processed/sales_clean.csv",index = False)

# %%
clean_inventory.to_csv("C:/Users/admin/OneDrive/Desktop/smart-inventory/data/processed/inventorys_clean.csv",index = False)

# %%
import os

os.listdir("../data/processed")
# Out:
# ['inventorys_clean.csv', 'products_clean.csv', 'sales_clean.csv']
